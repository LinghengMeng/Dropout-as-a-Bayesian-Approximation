# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.contrib.distributions import Bernoulli


class VariationalDense:
    """Variational Dense Layer Class"""
    def __init__(self, n_in, n_out, model_prob, model_lam):
        self.model_prob = model_prob    # probability to keep units
        self.model_lam = model_lam      # l^2 / 2*tau
        self.model_bern = Bernoulli(probs=self.model_prob, dtype=tf.float32)
        self.model_M = tf.Variable(tf.truncated_normal([n_in, n_out], stddev=0.01))
        self.model_m = tf.Variable(tf.zeros([n_out]))
        self.model_W = tf.matmul(
            tf.diag(self.model_bern.sample((n_in, ))), self.model_M
        )

    def __call__(self, X, activation=tf.identity):
        output = activation(tf.matmul(X, self.model_W) + self.model_m)
        if self.model_M.shape[1] == 1:
            output = tf.squeeze(output)
        return output

    @property
    def regularization(self):
        return self.model_lam * (
            self.model_prob * tf.reduce_sum(tf.square(self.model_M)) +
            tf.reduce_sum(tf.square(self.model_m))
        )

# Created sample data.
n_samples = 2000
X = np.random.normal(size=(n_samples, 1))
y = np.random.normal(np.cos(5.*X) / (np.abs(X) + 1.), 0.1).ravel()
X_pred = np.atleast_2d(np.linspace(-3., 3., num=100)).T
X = np.hstack((X, X**2, X**3))
X_pred = np.hstack((X_pred, X_pred**2, X_pred**3))

# Create the TensorFlow model.
n_feats = X.shape[1]
n_hidden = 100
model_prob = 0.9
model_lam = 1e-2
model_X = tf.placeholder(tf.float32, [None, n_feats])
model_y = tf.placeholder(tf.float32, [None])
model_L_1 = VariationalDense(n_feats, n_hidden, model_prob, model_lam)
model_L_2 = VariationalDense(n_hidden, n_hidden, model_prob, model_lam)
model_L_3 = VariationalDense(n_hidden, 1, model_prob, model_lam)
model_out_1 = model_L_1(model_X, tf.nn.relu)
model_out_2 = model_L_2(model_out_1, tf.nn.relu)
model_pred = model_L_3(model_out_2)
model_sse = tf.reduce_sum(tf.square(model_y - model_pred))
model_mse = model_sse / n_samples
model_loss = (
    # Negative log-likelihood.
    model_sse +
    # Regularization.
    model_L_1.regularization +
    model_L_2.regularization +
    model_L_3.regularization
) / n_samples
train_step = tf.train.AdamOptimizer(1e-3).minimize(model_loss)

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())
for i in range(10000):
    sess.run(train_step, {model_X: X, model_y: y})
    if i % 100 == 0:
        mse = sess.run(model_mse, {model_X: X, model_y: y})
        print("Iteration {}. Mean squared error: {:.4f}.".format(i, mse))
# Out:
# Iteration 0. Mean squared error: 0.2276.
# Iteration 100. Mean squared error: 0.1203.
# Iteration 200. Mean squared error: 0.1262.
# Iteration 300. Mean squared error: 0.0719.
# Iteration 400. Mean squared error: 0.0881.
# Iteration 500. Mean squared error: 0.0388.
# Iteration 600. Mean squared error: 0.0569.
# Iteration 700. Mean squared error: 0.0447.
# Iteration 800. Mean squared error: 0.0213.
# Iteration 900. Mean squared error: 0.0228.
# Iteration 1000. Mean squared error: 0.0503.
# Iteration 1100. Mean squared error: 0.0329.
# Iteration 1200. Mean squared error: 0.0158.
# Iteration 1300. Mean squared error: 0.0227.
# Iteration 7700. Mean squared error: 0.0155.
# Iteration 7800. Mean squared error: 0.0195.
# Iteration 7900. Mean squared error: 0.0141.
# Iteration 8000. Mean squared error: 0.0134.
# Iteration 8100. Mean squared error: 0.0133.
# Iteration 8200. Mean squared error: 0.0187.
# Iteration 8300. Mean squared error: 0.0253.
# Iteration 8400. Mean squared error: 0.0251.
# Iteration 8500. Mean squared error: 0.0177.
# Iteration 8600. Mean squared error: 0.0129.
# Iteration 8700. Mean squared error: 0.0191.
# Iteration 8800. Mean squared error: 0.0133.
# Iteration 8900. Mean squared error: 0.0186.
# Iteration 9000. Mean squared error: 0.0333.
# Iteration 9100. Mean squared error: 0.0184.
# Iteration 9200. Mean squared error: 0.0149.
# Iteration 9300. Mean squared error: 0.0204.
# Iteration 9400. Mean squared error: 0.0227.
# Iteration 9500. Mean squared error: 0.0118.
# Iteration 9600. Mean squared error: 0.0167.
# Iteration 9700. Mean squared error: 0.0190.
# Iteration 9800. Mean squared error: 0.0315.
# Iteration 9900. Mean squared error: 0.0145.

# %%
# Sample from the posterior.
n_post = 10000
Y_post = np.zeros((n_post, X_pred.shape[0]))
for i in range(n_post):
    Y_post[i] = sess.run(model_pred, {model_X: X_pred})

if True:67
    plt.figure(figsize=(8, 6))
    for i in range(n_post):
        plt.plot(X_pred[:, 0], Y_post[i], "b-", alpha=1. / 10)
    # plt.plot(X[:, 0], y, "r.")
    plt.title('n_samples={}, n_post={}'.format(n_samples, n_post))
    plt.grid()
    plt.show()

# %%
# Sample from the posterior.
n_post = 1000
Y_post = np.zeros((n_post, X_pred.shape[0]))
for i in range(n_post):
    Y_post[i] = sess.run(model_pred, {model_X: X_pred})

if True:
    plt.figure(figsize=(8, 6))
    for i in range(n_post):
        plt.plot(X_pred[:, 0], Y_post[i], "b-", alpha=1. / 10)
    # plt.plot(X[:, 0], y, "r.")
    plt.title('n_samples={}, n_post={}'.format(n_samples, n_post))
    plt.grid()
    plt.show()

# %%
# Sample from the posterior.
n_post = 100
Y_post = np.zeros((n_post, X_pred.shape[0]))
for i in range(n_post):
    Y_post[i] = sess.run(model_pred, {model_X: X_pred})

if True:
    plt.figure(figsize=(8, 6))
    for i in range(n_post):
        plt.plot(X_pred[:, 0], Y_post[i], "b-", alpha=1. / 10)
    # plt.plot(X[:, 0], y, "r.")
    plt.title('n_samples={}, n_post={}'.format(n_samples, n_post))
    plt.grid()
    plt.show()

# %%
# Sample from the posterior.
n_post = 10
Y_post = np.zeros((n_post, X_pred.shape[0]))
for i in range(n_post):
    Y_post[i] = sess.run(model_pred, {model_X: X_pred})

if True:
    plt.figure(figsize=(8, 6))
    for i in range(n_post):
        plt.plot(X_pred[:, 0], Y_post[i], "b-", alpha=1. / 10)
    # plt.plot(X[:, 0], y, "r.")
    plt.title('n_samples={}, n_post={}'.format(n_samples, n_post))
    plt.grid()
    plt.show()
